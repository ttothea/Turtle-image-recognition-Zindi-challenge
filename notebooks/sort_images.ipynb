# %% [markdown]
# # Sort images
#
# This notebook will create a (sub)folder structure for the train and test images.
# It will sort the train images into train and val folders, such that each turtle gets one image per image location in each turtle id validation subfolder.
# The rest of the training images is sorted into the train folder.
# The goal is to optimize the train/validation split.
#
# The test images are sorted via their image id.

# %%
#importing the necessary modules
import shutil
from imutils import paths
from random import shuffle
import os
from datetime import datetime
import numpy as np
import pathlib
import pandas as pd

# %% [markdown]
# ## Sort train images into train and validation folders

# %%
train_data = pd.read_csv('../data/train_corrected.csv')
train_data.image_id = train_data.image_id.apply(lambda x: x.strip()+".jpg")
train_data['turtle_id-image_id'] = train_data.turtle_id + "-" + train_data.image_id
train_data['turtle_id-image_location'] = train_data.turtle_id + "-" + train_data.image_location
train_data['turtle_id-image_location+image_id'] = train_data.turtle_id + "-" + train_data.image_location + "+" + train_data.image_id

# %%
train_data
# Out:
#              image_id image_location      turtle_id  \
# 0     ID_009TNNQ8.jpg           left  t_id_Kf73l69A
# 1     ID_010JDNBL.jpg          right  t_id_GrxmyS59
# 2     ID_01L54J3D.jpg           left  t_id_d6aYXtor
# 3     ID_02445SY2.jpg            top  t_id_GrxmyS59
# 4     ID_026RZIZ9.jpg          right  t_id_hRzOoJ2t
# ...               ...            ...            ...
# 2117  ID_ZWHZBX92.jpg            top  t_id_Kc1tXDbJ
# 2118  ID_ZXM8MLS2.jpg            top  t_id_2QmcRkNj
# 2119  ID_ZY15TQYT.jpg           left  t_id_stWei2Uq
# 2120  ID_ZYTRP3VN.jpg           left  t_id_ip3jsrYo
# 2121  ID_ZZEGHRM5.jpg           left  t_id_m2JvEcsg
#
#                  turtle_id-image_id turtle_id-image_location  \
# 0     t_id_Kf73l69A-ID_009TNNQ8.jpg       t_id_Kf73l69A-left
# 1     t_id_GrxmyS59-ID_010JDNBL.jpg      t_id_GrxmyS59-right
# 2     t_id_d6aYXtor-ID_01L54J3D.jpg       t_id_d6aYXtor-left
# 3     t_id_GrxmyS59-ID_02445SY2.jpg        t_id_GrxmyS59-top
# 4     t_id_hRzOoJ2t-ID_026RZIZ9.jpg      t_id_hRzOoJ2t-right
# ...                             ...                      ...
# 2117  t_id_Kc1tXDbJ-ID_ZWHZBX92.jpg        t_id_Kc1tXDbJ-top
# 2118  t_id_2QmcRkNj-ID_ZXM8MLS2.jpg        t_id_2QmcRkNj-top
# 2119  t_id_stWei2Uq-ID_ZY15TQYT.jpg       t_id_stWei2Uq-left
# 2120  t_id_ip3jsrYo-ID_ZYTRP3VN.jpg       t_id_ip3jsrYo-left
# 2121  t_id_m2JvEcsg-ID_ZZEGHRM5.jpg       t_id_m2JvEcsg-left
#
#         turtle_id-image_location+image_id
# 0      t_id_Kf73l69A-left+ID_009TNNQ8.jpg
# 1     t_id_GrxmyS59-right+ID_010JDNBL.jpg
# 2      t_id_d6aYXtor-left+ID_01L54J3D.jpg
# 3       t_id_GrxmyS59-top+ID_02445SY2.jpg
# 4     t_id_hRzOoJ2t-right+ID_026RZIZ9.jpg
# ...                                   ...
# 2117    t_id_Kc1tXDbJ-top+ID_ZWHZBX92.jpg
# 2118    t_id_2QmcRkNj-top+ID_ZXM8MLS2.jpg
# 2119   t_id_stWei2Uq-left+ID_ZY15TQYT.jpg
# 2120   t_id_ip3jsrYo-left+ID_ZYTRP3VN.jpg
# 2121   t_id_m2JvEcsg-left+ID_ZZEGHRM5.jpg
#
# [2122 rows x 6 columns]

# %%
#list all pictures in the image_dir
image_dir = '../images/'
imagePaths = sorted(list(paths.list_images(image_dir)))

# %%
# Store all the turtle_ids in train_data
turtle_ids = train_data['turtle_id']
turtle_ids
# Out:
# 0       t_id_Kf73l69A
# 1       t_id_GrxmyS59
# 2       t_id_d6aYXtor
# 3       t_id_GrxmyS59
# 4       t_id_hRzOoJ2t
#             ...
# 2117    t_id_Kc1tXDbJ
# 2118    t_id_2QmcRkNj
# 2119    t_id_stWei2Uq
# 2120    t_id_ip3jsrYo
# 2121    t_id_m2JvEcsg
# Name: turtle_id, Length: 2122, dtype: object

# %% [markdown]
# ## Sort images
# To sort the images you need to create a subfolder "sorted_images" into the main folder

# %%
#after listing all individuals create two empty folders for each individual 
#one for the training and another for the validaiton dataset

#define the folder were the training and validation datasets will be placed
if not os.path.exists("../sorted_images_locationwise"):
    os.makedirs("../sorted_images_locationwise")
root_dir="../sorted_images_locationwise"

#loop through all individuals and create a folder for the training dataset
# and a folder for the validation dataset
for i in range(0, len(turtle_ids)):
    train_dir=root_dir+"/train/"+turtle_ids[i]#variable with the full path of the training folder
    val_dir=root_dir+"/val/"+turtle_ids[i]#variable with the full path of the validation folder
    if not os.path.exists(train_dir):#condition for if the folder already exists
        os.makedirs(train_dir)#create the folder
    if not os.path.exists(val_dir):
        os.makedirs(val_dir)

# %%
# These lines will create a folder called "new_turtle" into our train and validation sub-folders. 
#This is necessary for our specific task. (Reminder: if the image most likelx does not belong to any turtle_id, the models needs to output "new_turtle")
#These folders will not contain any pictures
#os.makedirs("../sorted_images/train/new_turtle")
#os.makedirs("../sorted_images/val/new_turtle")

# %%
#Check length of train_data, i.e. number of relevant pictures
round(len(train_data))
# Out:
# 2122

# %%
train_data
# Out:
#              image_id image_location      turtle_id  \
# 0     ID_009TNNQ8.jpg           left  t_id_Kf73l69A
# 1     ID_010JDNBL.jpg          right  t_id_GrxmyS59
# 2     ID_01L54J3D.jpg           left  t_id_d6aYXtor
# 3     ID_02445SY2.jpg            top  t_id_GrxmyS59
# 4     ID_026RZIZ9.jpg          right  t_id_hRzOoJ2t
# ...               ...            ...            ...
# 2117  ID_ZWHZBX92.jpg            top  t_id_Kc1tXDbJ
# 2118  ID_ZXM8MLS2.jpg            top  t_id_2QmcRkNj
# 2119  ID_ZY15TQYT.jpg           left  t_id_stWei2Uq
# 2120  ID_ZYTRP3VN.jpg           left  t_id_ip3jsrYo
# 2121  ID_ZZEGHRM5.jpg           left  t_id_m2JvEcsg
#
#                  turtle_id-image_id turtle_id-image_location
# 0     t_id_Kf73l69A-ID_009TNNQ8.jpg       t_id_Kf73l69A-left
# 1     t_id_GrxmyS59-ID_010JDNBL.jpg      t_id_GrxmyS59-right
# 2     t_id_d6aYXtor-ID_01L54J3D.jpg       t_id_d6aYXtor-left
# 3     t_id_GrxmyS59-ID_02445SY2.jpg        t_id_GrxmyS59-top
# 4     t_id_hRzOoJ2t-ID_026RZIZ9.jpg      t_id_hRzOoJ2t-right
# ...                             ...                      ...
# 2117  t_id_Kc1tXDbJ-ID_ZWHZBX92.jpg        t_id_Kc1tXDbJ-top
# 2118  t_id_2QmcRkNj-ID_ZXM8MLS2.jpg        t_id_2QmcRkNj-top
# 2119  t_id_stWei2Uq-ID_ZY15TQYT.jpg       t_id_stWei2Uq-left
# 2120  t_id_ip3jsrYo-ID_ZYTRP3VN.jpg       t_id_ip3jsrYo-left
# 2121  t_id_m2JvEcsg-ID_ZZEGHRM5.jpg       t_id_m2JvEcsg-left
#
# [2122 rows x 5 columns]

# %%
#in this example we are going to select 1822 (approx 86%) pictures for training and 300 (approx 14%) pictures for validation.
#We setup the condition that the validation pictures should contain at least one picture per turtle_id for each image_location
#as per now we have nothing to avoid having pictures that are very similiar in both datasets, which could result in overfitting the CNN

#define the number of validation pictures and the number of training pictures
N_val_pics=300
N_train_pics=1822

#create two empty lists to store the pictures files that are going to be moved to the training 
#and validation fodlers
training_pictures=[]
validation_pictures=[]

#list to check if combination is already used
turtle_id_image_location=[]

#loop through each individual turtle_id and secondary image_location
for index in range(0, len(train_data)):
    if train_data['turtle_id-image_location'][index] not in turtle_id_image_location:
        validation_pictures.append(train_data['turtle_id-image_id'][index])
        turtle_id_image_location.append(train_data['turtle_id-image_location'][index])
    else:
        training_pictures.append(train_data['turtle_id-image_id'][index])

# %%
#loop through each individual turtle_id and secondary image_location
for index in range(0, len(train_data)):
    if train_data['turtle_id-image_location'][index] not in turtle_id_image_location:
        validation_pictures.append(train_data['image_id-image_location'][index])
        turtle_id_image_location.append(train_data['turtle_id-image_location'][index])
    else:
        training_pictures.append(train_data['turtle_id-image_id'][index])

# %%
#Check if number of validation pictures is indeed 300
len(validation_pictures)
# Out:
# 300

# %%
len(training_pictures)
# Out:
# 1822

# %%
validation_pictures
# Out:
# ['t_id_Kf73l69A-ID_009TNNQ8.jpg',
#  't_id_GrxmyS59-ID_010JDNBL.jpg',
#  't_id_d6aYXtor-ID_01L54J3D.jpg',
#  't_id_GrxmyS59-ID_02445SY2.jpg',
#  't_id_hRzOoJ2t-ID_026RZIZ9.jpg',
#  't_id_dhdJMT1K-ID_04LIX78Y.jpg',
#  't_id_fjHGjp1w-ID_05OAB9HN.jpg',
#  't_id_m2JvEcsg-ID_08R685XU.jpg',
#  't_id_Ts5LyVQz-ID_08VEIX80.jpg',
#  't_id_fxTQ5vHC-ID_092X1NP4.jpg',
#  't_id_AOWArhGb-ID_0B15SK84.jpg',
#  't_id_uJXT7dGu-ID_0D2ZJPGL.jpg',
#  't_id_stWei2Uq-ID_0DOWCQVL.jpg',
#  't_id_2QmcRkNj-ID_0E36WAY8.jpg',
#  't_id_8b8sprYe-ID_0F3ODH2R.jpg',
#  't_id_Ts5LyVQz-ID_0FP7W8WI.jpg',
#  't_id_n2FBHk6d-ID_0FX6ODC0.jpg',
#  't_id_G5JLzvai-ID_0G8SI7HQ.jpg',
#  't_id_n2FBHk6d-ID_0I5FAS7W.jpg',
#  't_id_3K93fQBS-ID_0ILV12LP.jpg',
#  't_id_dVQ4x3wz-ID_0INOHY6I.jpg',
#  't_id_dVQ4x3wz-ID_0J1NXY6D.jpg',
#  't_id_tjWepji1-ID_0JC13MBA.jpg',
#  't_id_uIlC9Gfo-ID_0JDDE04I.jpg',
#  't_id_MwnEYfqe-ID_0KMB0NN4.jpg',
#  't_id_72SiiZCp-ID_0KQJ1TYW.jpg',
#  't_id_g9Fz8PH7-ID_0LHYKDEU.jpg',
#  't_id_GOIvCduN-ID_0MGFWAOV.jpg',
#  't_id_ksTLswDT-ID_0NFH1PZ6.jpg',
#  't_id_e9i3Lbq4-ID_0OAKNJBQ.jpg',
#  't_id_hRzOoJ2t-ID_0R6UOFUQ.jpg',
#  't_id_72SiiZCp-ID_0S3VQPSJ.jpg',
#  't_id_8b8sprYe-ID_0S4IF2K2.jpg',
#  't_id_0g31STvR-ID_0S8W21AW.jpg',
#  't_id_Ts5LyVQz-ID_0SYENLY6.jpg',
#  't_id_1KIezxkh-ID_0VJ2FLV9.jpg',
#  't_id_AMnriNb5-ID_0VVR6NIJ.jpg',
#  't_id_IlO9BOKc-ID_0WB4N789.jpg',
#  't_id_15bo4NKD-ID_0WG9U1GO.jpg',
#  't_id_a4VYrmyA-ID_0XJG7PXU.jpg',
#  't_id_tjWepji1-ID_0XWII0XC.jpg',
#  't_id_4ZfTUmwL-ID_0Y7QBGIB.jpg',
#  't_id_G5eoqwD8-ID_0Y7REA36.jpg',
#  't_id_stWei2Uq-ID_0YAZWB2L.jpg',
#  't_id_ROFhVsy2-ID_0YJ5D3IF.jpg',
#  't_id_uIlC9Gfo-ID_10EJKPAF.jpg',
#  't_id_qZ0iZYsC-ID_10HIRN6W.jpg',
#  't_id_IlO9BOKc-ID_10S4M153.jpg',
#  't_id_D0gA44av-ID_12TAY32Q.jpg',
#  't_id_AOWArhGb-ID_14F3K393.jpg',
#  't_id_JI6ba2Yx-ID_14NTXGCE.jpg',
#  't_id_KysHzQQK-ID_184JGJF5.jpg',
#  't_id_tjWepji1-ID_19M73WWV.jpg',
#  't_id_ROFhVsy2-ID_19YCCES6.jpg',
#  't_id_HxxqrdTx-ID_1BGNVTGM.jpg',
#  't_id_HcnnlRda-ID_1BI2BZ0J.jpg',
#  't_id_niEvmwXu-ID_1D4KU714.jpg',
#  't_id_stWei2Uq-ID_1DDCV5Q1.jpg',
#  't_id_IP3xtKuX-ID_1DHBY4KU.jpg',
#  't_id_Kc1tXDbJ-ID_1E6X2GLW.jpg',
#  't_id_m2JvEcsg-ID_1EAHT0TG.jpg',
#  't_id_BI99coHt-ID_1GVXTFKL.jpg',
#  't_id_3fKmnkBS-ID_1HC59N7M.jpg',
#  't_id_iD9ikw6Y-ID_1HCBWQRK.jpg',
#  't_id_DbmclTcj-ID_1HSQYZPE.jpg',
#  't_id_WDCMGvI4-ID_1HVIO966.jpg',
#  't_id_D0gA44av-ID_1IP252Y3.jpg',
#  't_id_a4VYrmyA-ID_1JC1FD54.jpg',
#  't_id_BXWccqAn-ID_1JOTYWTI.jpg',
#  't_id_n2FBHk6d-ID_1K6QG62O.jpg',
#  't_id_qZ0iZYsC-ID_1KH9MS93.jpg',
#  't_id_uVgs53Cz-ID_1KKOIHIV.jpg',
#  't_id_ifWwxWF4-ID_1LOGRZ1C.jpg',
#  't_id_uMOOrQu7-ID_1LVKGE2I.jpg',
#  't_id_ifWwxWF4-ID_1OKAKEHX.jpg',
#  't_id_Dv4O8bOM-ID_1OND9SX7.jpg',
#  't_id_pCO59rOk-ID_1P5BX7XH.jpg',
#  't_id_0g31STvR-ID_1PXR5D4Y.jpg',
#  't_id_WXXcPTSW-ID_1Q7KV157.jpg',
#  't_id_C0wevyOl-ID_1R8WKXOZ.jpg',
#  't_id_bYageLYA-ID_1RRY7HY8.jpg',
#  't_id_JI6ba2Yx-ID_1RSRZF5W.jpg',
#  't_id_B7LaSiac-ID_1RZIFCHC.jpg',
#  't_id_fjHGjp1w-ID_1S6V7HAH.jpg',
#  't_id_JI6ba2Yx-ID_1SPFXL92.jpg',
#  't_id_mXD9Bjsb-ID_1SQB2VWI.jpg',
#  't_id_IP1t15lD-ID_1V7S2G5A.jpg',
#  't_id_AOWArhGb-ID_1WUOBP46.jpg',
#  't_id_BXWccqAn-ID_1X2W3ABD.jpg',
#  't_id_BXWccqAn-ID_1Y1QRZWC.jpg',
#  't_id_72SiiZCp-ID_1Z849QK6.jpg',
#  't_id_VP2NW7aV-ID_20MTQNWG.jpg',
#  't_id_Kf73l69A-ID_21FM67IR.jpg',
#  't_id_IP3xtKuX-ID_22W82BIH.jpg',
#  't_id_IlO9BOKc-ID_232HUB3N.jpg',
#  't_id_C0wevyOl-ID_24XMOLVK.jpg',
#  't_id_Kf73l69A-ID_2598ECXH.jpg',
#  't_id_hibDzPAP-ID_25T5KR2Q.jpg',
#  't_id_dhdJMT1K-ID_26FZY0AJ.jpg',
#  't_id_dc6pjonY-ID_26I2GKJZ.jpg',
#  't_id_YjXYTCGC-ID_26JZTBIX.jpg',
#  't_id_fjHGjp1w-ID_27U9A3K5.jpg',
#  't_id_7gFFZy7i-ID_2AWOJQ6G.jpg',
#  't_id_VFb44eFm-ID_2D8P5IJQ.jpg',
#  't_id_2E8o5Jtl-ID_2DHZ5XI3.jpg',
#  't_id_NW7wn8TC-ID_2DTFZN5E.jpg',
#  't_id_8b8sprYe-ID_2FBSU5IN.jpg',
#  't_id_Kc1tXDbJ-ID_2G5VWR8P.jpg',
#  't_id_YjXYTCGC-ID_2GB90GPS.jpg',
#  't_id_mpuNp8mf-ID_2GM0SK7V.jpg',
#  't_id_hibDzPAP-ID_2LDLI6PP.jpg',
#  't_id_dc6pjonY-ID_2M1QR0UQ.jpg',
#  't_id_15bo4NKD-ID_2MI7QHMY.jpg',
#  't_id_9GFmcOd5-ID_2MP8SEYX.jpg',
#  't_id_m2JvEcsg-ID_2NFH5AY5.jpg',
#  't_id_ip3jsrYo-ID_2O9XULTA.jpg',
#  't_id_1KIezxkh-ID_2QCEKGLA.jpg',
#  't_id_ZfvZBX4Q-ID_2QZRGCJ2.jpg',
#  't_id_VP2NW7aV-ID_2RK4WLN8.jpg',
#  't_id_BI99coHt-ID_2WZGLEX7.jpg',
#  't_id_Lhp87PBX-ID_2XQIT20D.jpg',
#  't_id_4ZfTUmwL-ID_2YD83LJI.jpg',
#  't_id_VFb44eFm-ID_32T8KDHK.jpg',
#  't_id_G5eoqwD8-ID_332W0EFB.jpg',
#  't_id_gz3whk0q-ID_339CY33I.jpg',
#  't_id_BI99coHt-ID_3646J5ZS.jpg',
#  't_id_DPYQnZyv-ID_364YVU2F.jpg',
#  't_id_87CLFCvE-ID_36IV1E98.jpg',
#  't_id_ksTLswDT-ID_36LEVX0D.jpg',
#  't_id_KysHzQQK-ID_36OO9FMT.jpg',
#  't_id_iZQiE7wb-ID_37OGYEDP.jpg',
#  't_id_D3kHUEgp-ID_37RXZ3TO.jpg',
#  't_id_15bo4NKD-ID_38NFN6PE.jpg',
#  't_id_J24awAHQ-ID_38OZ45LI.jpg',
#  't_id_OqU1NWEA-ID_395HP0WK.jpg',
#  't_id_3b65X5Lw-ID_3AHN59NJ.jpg',
#  't_id_SwQZGIpa-ID_3B6AWEAY.jpg',
#  't_id_a4VYrmyA-ID_3CSDCABB.jpg',
#  't_id_g9Fz8PH7-ID_3E0B7W1E.jpg',
#  't_id_IP1t15lD-ID_3G500MQW.jpg',
#  't_id_QqeoI5F3-ID_3G585E73.jpg',
#  't_id_utw0thCe-ID_3KPZ2UKO.jpg',
#  't_id_MwnEYfqe-ID_3KTXJW0H.jpg',
#  't_id_7gFFZy7i-ID_3L5MO2LW.jpg',
#  't_id_dVQ4x3wz-ID_3NDJQJM7.jpg',
#  't_id_uJXT7dGu-ID_3NN7SJN0.jpg',
#  't_id_WXXcPTSW-ID_3QBOOK4D.jpg',
#  't_id_Imm5pnNf-ID_3R63YUGO.jpg',
#  't_id_ZfvZBX4Q-ID_3RTMTX0P.jpg',
#  't_id_ip3jsrYo-ID_3SN9CPQK.jpg',
#  't_id_GrxmyS59-ID_3SSUOD1F.jpg',
#  't_id_fxTQ5vHC-ID_3VW2J1FZ.jpg',
#  't_id_mXD9Bjsb-ID_3WMD0EOX.jpg',
#  't_id_NW7wn8TC-ID_3YAV8O0C.jpg',
#  't_id_ROFhVsy2-ID_40BUCYTX.jpg',
#  't_id_7gFFZy7i-ID_4123DJRO.jpg',
#  't_id_9GFmcOd5-ID_41LEJCPQ.jpg',
#  't_id_k1rScFLB-ID_43A2KYN1.jpg',
#  't_id_SwQZGIpa-ID_442DRHCA.jpg',
#  't_id_D3kHUEgp-ID_46GASB8T.jpg',
#  't_id_utw0thCe-ID_489J52MZ.jpg',
#  't_id_G5eoqwD8-ID_48KBQF5K.jpg',
#  't_id_gGQbn7FA-ID_49SFWMMF.jpg',
#  't_id_ip3jsrYo-ID_4F311WF5.jpg',
#  't_id_AMnriNb5-ID_4G43AB8P.jpg',
#  't_id_IP3xtKuX-ID_4I3ESY77.jpg',
#  't_id_EEbWq5Pj-ID_4LFAG0GT.jpg',
#  't_id_2Yn71r7R-ID_4MWH30AA.jpg',
#  't_id_QqeoI5F3-ID_4N7JWS83.jpg',
#  't_id_KysHzQQK-ID_4PYQJ8EO.jpg',
#  't_id_3fKmnkBS-ID_4RSKLTX9.jpg',
#  't_id_k1rScFLB-ID_4SG74XJ1.jpg',
#  't_id_3b65X5Lw-ID_4U56R1MS.jpg',
#  't_id_dhdJMT1K-ID_4W4GWHPZ.jpg',
#  't_id_QqeoI5F3-ID_4XFAYVLG.jpg',
#  't_id_87CLFCvE-ID_53HQWAOW.jpg',
#  't_id_uJXT7dGu-ID_54EE1LXT.jpg',
#  't_id_IP1t15lD-ID_54LAOD9M.jpg',
#  't_id_smNwfXAT-ID_575UBYT3.jpg',
#  't_id_mpuNp8mf-ID_585DWP1V.jpg',
#  't_id_HxxqrdTx-ID_59PAXSBH.jpg',
#  't_id_J5dngbNA-ID_5B9ZLN2R.jpg',
#  't_id_iD9ikw6Y-ID_5EXO9GOM.jpg',
#  't_id_1KIezxkh-ID_5F3UK4KI.jpg',
#  't_id_hRzOoJ2t-ID_5JTLGUUD.jpg',
#  't_id_G5JLzvai-ID_5N0ZOGBZ.jpg',
#  't_id_DPYQnZyv-ID_5NER06CD.jpg',
#  't_id_FBsGDJhU-ID_5OYHSZLM.jpg',
#  't_id_OqU1NWEA-ID_5PFFGQ9H.jpg',
#  't_id_Imm5pnNf-ID_5QUIP8AJ.jpg',
#  't_id_iZQiE7wb-ID_5XBNA2NJ.jpg',
#  't_id_smNwfXAT-ID_5Y4N29AA.jpg',
#  't_id_ifWwxWF4-ID_5ZX8LSS7.jpg',
#  't_id_VP2NW7aV-ID_63BFNF8E.jpg',
#  't_id_C0wevyOl-ID_66CXU9J1.jpg',
#  't_id_YjXYTCGC-ID_682LHQ6M.jpg',
#  't_id_WDCMGvI4-ID_6BHLTFXH.jpg',
#  't_id_k1rScFLB-ID_6BKRV6RP.jpg',
#  't_id_WDCMGvI4-ID_6DVOCAKS.jpg',
#  't_id_UVQa4BMz-ID_6GFKRO0E.jpg',
#  't_id_AMnriNb5-ID_6GKENQ04.jpg',
#  't_id_MwnEYfqe-ID_6GZWW0BC.jpg',
#  't_id_pCO59rOk-ID_6HEJXWEZ.jpg',
#  't_id_mXD9Bjsb-ID_6I8GO8DU.jpg',
#  't_id_qZ0iZYsC-ID_6IGHJWBY.jpg',
#  't_id_X3bKBWYW-ID_6KEFH5SM.jpg',
#  't_id_0DPPpRUz-ID_6L5VQ5R8.jpg',
#  't_id_2QmcRkNj-ID_6SSK0AVO.jpg',
#  't_id_Kc1tXDbJ-ID_6XIQRRRF.jpg',
#  't_id_mpuNp8mf-ID_74D61SAT.jpg',
#  't_id_iZQiE7wb-ID_77LS79M6.jpg',
#  't_id_J5dngbNA-ID_78YFIJ0A.jpg',
#  't_id_bYageLYA-ID_7BSHGZXH.jpg',
#  't_id_D0gA44av-ID_7CXJQYNT.jpg',
#  't_id_pCO59rOk-ID_7FE177TK.jpg',
#  't_id_gJaKYxBQ-ID_7HN2MEC6.jpg',
#  't_id_utw0thCe-ID_7MLEFE2D.jpg',
#  't_id_EEbWq5Pj-ID_7N1REGEV.jpg',
#  't_id_J24awAHQ-ID_7P8QE2GS.jpg',
#  't_id_uVgs53Cz-ID_7TUD0AU0.jpg',
#  't_id_ZfvZBX4Q-ID_7Y87NI7I.jpg',
#  't_id_uMOOrQu7-ID_7YLCHKFY.jpg',
#  't_id_9GFmcOd5-ID_875JHHIC.jpg',
#  't_id_gGQbn7FA-ID_87TGZA2M.jpg',
#  't_id_4XiPKIk7-ID_891VOTKK.jpg',
#  't_id_VFb44eFm-ID_8HAJ1J4P.jpg',
#  't_id_ksTLswDT-ID_8M2Z12BM.jpg',
#  't_id_iD9ikw6Y-ID_8MK9Y405.jpg',
#  't_id_FBsGDJhU-ID_8P99DAQ6.jpg',
#  't_id_0DPPpRUz-ID_8QREX315.jpg',
#  't_id_D7NA71la-ID_8RMH5NGD.jpg',
#  't_id_G5JLzvai-ID_92HCXOZ1.jpg',
#  't_id_DbmclTcj-ID_95V5MCCU.jpg',
#  't_id_GOIvCduN-ID_9D7O7BNO.jpg',
#  't_id_FBsGDJhU-ID_9DYBDN69.jpg',
#  't_id_2Yn71r7R-ID_9FUITRRD.jpg',
#  't_id_d6aYXtor-ID_9H5QANIG.jpg',
#  't_id_g9Fz8PH7-ID_9IMJWIB1.jpg',
#  't_id_Lhp87PBX-ID_9JRSLKW0.jpg',
#  't_id_NW7wn8TC-ID_9QPYWFMK.jpg',
#  't_id_GOIvCduN-ID_9TVXYZ73.jpg',
#  't_id_niEvmwXu-ID_9U6AFLQ2.jpg',
#  't_id_2E8o5Jtl-ID_9VLHFF1Q.jpg',
#  't_id_3fKmnkBS-ID_9WFGTQXE.jpg',
#  't_id_SwQZGIpa-ID_A0A4OOQO.jpg',
#  't_id_B7LaSiac-ID_A2X10RIZ.jpg',
#  't_id_2QmcRkNj-ID_ADILYXGS.jpg',
#  't_id_87CLFCvE-ID_AE37TD10.jpg',
#  't_id_Imm5pnNf-ID_AHAESL2D.jpg',
#  't_id_2Yn71r7R-ID_AMDTJIPS.jpg',
#  't_id_3K93fQBS-ID_AS53QVYU.jpg',
#  't_id_fxTQ5vHC-ID_AS80AMY1.jpg',
#  't_id_UVQa4BMz-ID_AW3XEVWT.jpg',
#  't_id_gGQbn7FA-ID_AZ14M63B.jpg',
#  't_id_DPYQnZyv-ID_B3G84M72.jpg',
#  't_id_D7NA71la-ID_B3JL015U.jpg',
#  't_id_gJaKYxBQ-ID_BBSEK21T.jpg',
#  't_id_0g31STvR-ID_BC9JEODE.jpg',
#  't_id_OqU1NWEA-ID_BFEIUVKE.jpg',
#  't_id_3b65X5Lw-ID_BJOSVYCD.jpg',
#  't_id_e9i3Lbq4-ID_BPRJ7WOD.jpg',
#  't_id_dc6pjonY-ID_BQZWMZ6R.jpg',
#  't_id_DbmclTcj-ID_BS922PM8.jpg',
#  't_id_D3kHUEgp-ID_BZE59S10.jpg',
#  't_id_Lhp87PBX-ID_BZK50GKL.jpg',
#  't_id_uMOOrQu7-ID_C0XD1GPV.jpg',
#  't_id_niEvmwXu-ID_C49XVZ5R.jpg',
#  't_id_4ZfTUmwL-ID_C5MUH5W6.jpg',
#  't_id_p77GDtzg-ID_CPRH40QQ.jpg',
#  't_id_HxxqrdTx-ID_CQDCBC5D.jpg',
#  't_id_uIlC9Gfo-ID_DO1ZMLIJ.jpg',
#  't_id_uVgs53Cz-ID_DV9TFLZE.jpg',
#  't_id_2E8o5Jtl-ID_DZ3SS9KE.jpg',
#  't_id_e9i3Lbq4-ID_E2CEMBJF.jpg',
#  't_id_EEbWq5Pj-ID_E2DV9MCI.jpg',
#  't_id_Dv4O8bOM-ID_ENR6VVR6.jpg',
#  't_id_gJaKYxBQ-ID_FOD2ERLL.jpg',
#  't_id_UVQa4BMz-ID_G7D2IW6Z.jpg',
#  't_id_WXXcPTSW-ID_GYY52UV9.jpg',
#  't_id_HcnnlRda-ID_HD113138.jpg',
#  't_id_B7LaSiac-ID_HKE6LPE3.jpg',
#  't_id_smNwfXAT-ID_I3BS8QHQ.jpg',
#  't_id_bYageLYA-ID_I3D54T8B.jpg',
#  't_id_Dv4O8bOM-ID_I4R49D77.jpg',
#  't_id_p77GDtzg-ID_I9VYL0O6.jpg',
#  't_id_J24awAHQ-ID_IB0HNQVC.jpg',
#  't_id_0DPPpRUz-ID_ILCTHPLW.jpg',
#  't_id_d6aYXtor-ID_J077RZTD.jpg',
#  't_id_gz3whk0q-ID_JAV4V6Y8.jpg',
#  't_id_hibDzPAP-ID_K4TL0SZ1.jpg',
#  't_id_D7NA71la-ID_KIJOI5FD.jpg',
#  't_id_X3bKBWYW-ID_L32ZR5ZR.jpg',
#  't_id_4XiPKIk7-ID_LZ2KEHGP.jpg',
#  't_id_gz3whk0q-ID_MF15LWQ2.jpg',
#  't_id_3K93fQBS-ID_MQOTPTUW.jpg',
#  't_id_J5dngbNA-ID_O0ZBUMWU.jpg',
#  't_id_X3bKBWYW-ID_P98AEGPJ.jpg',
#  't_id_p77GDtzg-ID_PA2177BD.jpg',
#  't_id_HcnnlRda-ID_PKHY49FR.jpg',
#  't_id_4XiPKIk7-ID_VXLMBRF3.jpg']

# %%
validation_pictures[-1].split('-')[-2]
# Out:
# 't_id_4XiPKIk7'

# %%
val_images = []
train_images = []
#loop through the list of pictures
#move the pictures files to the validation folder
for i in range(0, len(validation_pictures)):
    #get the picture name
    val_file_name = image_dir + validation_pictures[i].split('-')[-1]
    image_name = validation_pictures[i].split('-')[-1]

    #create a variable with the directory and the name of the pictures file
    output_name_val=root_dir+"/val/"+validation_pictures[i].split('-')[-0]+"/"+image_name
       
    #move the file
    shutil.copy(val_file_name, output_name_val)
    
    # put the information into a DataFrame
    val_images.append(image_name)

for i in range(0, len(training_pictures)):
    #get the picture name (e.g. "01103F7D5A_2018-11-26_07-56-03.jpg")
    train_file_name = image_dir + training_pictures[i].split('-')[-1]
    image_name = training_pictures[i].split('-')[-1]

    #create a variable with the directory and the name of the pictures file
    output_name_train=root_dir+"/train/"+training_pictures[i].split('-')[-0]+"/"+image_name
       
    #move the file
    shutil.copy(train_file_name, output_name_train)    
    
    train_images.append(image_name)

# %%
val_images = []
train_images = []
#loop through the list of pictures
#move the pictures files to the validation folder
for i in range(0, len(validation_pictures)):
    #get the picture name
    val_file_name = image_dir + validation_pictures[i].split('-')[-1]
    image_name = validation_pictures[i].split('-')[-1]

    #create a variable with the directory and the name of the pictures file
    output_name_val=root_dir+"/val/"+validation_pictures[i].split('-')[-0]+"/"+image_name
       
    #move the file
    shutil.copy(val_file_name, output_name_val)
    
    # put the information into a DataFrame
    val_images.append(image_name)

for i in range(0, len(training_pictures)):
    #get the picture name (e.g. "01103F7D5A_2018-11-26_07-56-03.jpg")
    train_file_name = image_dir + training_pictures[i].split('-')[-1]
    image_name = training_pictures[i].split('-')[-1]

    #create a variable with the directory and the name of the pictures file
    output_name_train=root_dir+"/train/"+training_pictures[i].split('-')[-0]+"/"+image_name
       
    #move the file
    shutil.copy(train_file_name, output_name_train)    
    
    train_images.append(image_name)

# %% [markdown]
# ## Sort test images
# To appriately use our Train_CNN pipeline, we need to move our test pictures into a subfolder, as well.
#
# As we don't know the turtle_id for these pictures, we will save them into subfolders containing their image_id

# %%
test_data = pd.read_csv('../data/test_corrected.csv')
test_data_jpg = pd.read_csv('../data/test_corrected.csv')
test_data_jpg.image_id = test_data_jpg.image_id.apply(lambda x: x.strip()+".jpg")

# %%
#define the folder were the training and validation datasets will be placed
root_dir="../sorted_images/"
image_dir="../images/"
#loop through all individuals and create a folder for the test dataset
for i in range(0, len(test_data)):
    test_dir_folder= root_dir + "test/" + test_data['image_id'][i]#variable with the full path of the training folder
    if not os.path.exists(test_dir_folder):#condition for if the folder already exists
        os.makedirs(test_dir_folder)#create the folder

# %%
# put images into the folders

root_dir="../sorted_images/"
image_dir="../images/"

for i in range(0, len(test_data)):    
    image_name = test_data_jpg['image_id'][i]
    test_file_name = image_dir + image_name
    output_name = root_dir + "test/" + test_data['image_id'][i] + "/" + image_name
    #move the file
    shutil.copy(test_file_name, output_name)

# %% [markdown]
# ## Create dataframes with new folder structure

# %%
import os
import pandas as pd

# %%
train = []
train_dir="../sorted_images/train/"

for r, d, f in os.walk(train_dir):
    d.sort()
    for file in sorted(f):
        if ".jpg" in file:
            train.append((d,os.path.join(r,file)))

df_train = pd.DataFrame(train,columns=['folder','image_id'])

# %%
train = []
train_dir="../sorted_images/train/"

for r, d, f in os.walk(train_dir):
    d.sort()#key=str.lower)
    for file in sorted(f):
        if ".jpg" in file:
            train.append((d,os.path.join(r,file)))

df_train = pd.DataFrame(train,columns=['folder','image_id'])

val = []
val_dir="../sorted_images/val/"

for r, d, f in os.walk(val_dir):
    d.sort()#key=str.lower)
    for file in sorted(f):
        if ".jpg" in file:
            val.append((d,os.path.join(r,file)))

df_val = pd.DataFrame(val,columns=['folder','image_id'])

test = []
val_dir="../sorted_images/test/"

for r, d, f in os.walk(val_dir):
    d.sort()#key=str.lower)
    for file in sorted(f):
        if ".jpg" in file:
            test.append((d,os.path.join(r,file)))

df_test = pd.DataFrame(test,columns=['folder','image_id'])

# %%
df_train = df_train['image_id']
df_val = df_val['image_id']
df_test = df_test['image_id']

# %%
df_train
# Out:
# 0       ../sorted_images/train/t_id_0DPPpRUz/ID_96LWSV...
# 1       ../sorted_images/train/t_id_0DPPpRUz/ID_HONVLG...
# 2       ../sorted_images/train/t_id_0DPPpRUz/ID_R7GK2Y...
# 3       ../sorted_images/train/t_id_0DPPpRUz/ID_SBK2IX...
# 4       ../sorted_images/train/t_id_0DPPpRUz/ID_UIR6EX...
#                               ...
# 1817    ../sorted_images/train/t_id_utw0thCe/ID_TKDIA5...
# 1818    ../sorted_images/train/t_id_utw0thCe/ID_TN3XKG...
# 1819    ../sorted_images/train/t_id_utw0thCe/ID_VSXDS4...
# 1820    ../sorted_images/train/t_id_utw0thCe/ID_W69Q85...
# 1821    ../sorted_images/train/t_id_utw0thCe/ID_WKZM3K...
# Name: image_id, Length: 1822, dtype: object

# %%
train = []
for line in range(len(df_train)):
    train.append(df_train[line][-15:])

val = []
for line in range(len(df_val)):
    val.append(df_val[line][-15:])

test = []
for line in range(len(df_test)):
    test.append(df_test[line][-15:])

# %%
train[-1]
# Out:
# 'ID_WKZM3KRR.jpg'

# %%
image_location_train = []
for i in range(len(train)):
    for j in range(len(train_data)):
        if train[i] in train_data['image_id'][j]: 
            image_location_train.append(train_data['image_location'][j])
            
d_train = {'image_id':train,'image_location':image_location_train}   
df_train = pd.DataFrame(d_train)
df_train.to_csv('../data/df_sorted_train.csv', index = False)

# %%
image_location_val = []
for i in range(len(val)):
    for j in range(len(train_data)):
        if val[i] in train_data['image_id'][j]: 
            image_location_val.append(train_data['image_location'][j])
            
d_val = {'image_id':val,'image_location':image_location_val}   
df_val = pd.DataFrame(d_val)
df_val.to_csv('../data/df_sorted_val.csv', index = False)

# %%
image_location_test = []
for i in range(len(test)):
    for j in range(len(test_data_jpg)):
        if test[i] in test_data_jpg['image_id'][j]: 
            image_location_test.append(test_data_jpg['image_location'][j])
            
d_test = {'image_id':test,'image_location':image_location_test}   
df_test = pd.DataFrame(d_test)
df_test.to_csv('../data/df_sorted_test.csv', index = False)
